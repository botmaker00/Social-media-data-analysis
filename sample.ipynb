# %%
with open("finaldata.txt",encoding='utf-8') as f:
    data=f.read()

# %%
chunks=data.split('\n\n')
chunks = [c for c in chunks if len(c)>3]

# %%
def parse_chunk(chunk):
    chunk=chunk.strip()
    sep_chunk=chunk.split('\n')
    username=sep_chunk[0]
    posts=int(sep_chunk[1].split("post")[0].replace(",",""))
    followers=float(sep_chunk[2].split("followers")[0].replace(",","").replace("K","").replace("M",""))
    if("K" in sep_chunk[2]):
        followers=int(followers*1000)
    elif("M" in sep_chunk[2]):
        followers=int(followers*1000000)
    else:
        followers=int(followers)
        
    following=float(sep_chunk[3].split("following")[0].replace(",","").replace("K","").replace("m",""))
    if("K" in sep_chunk[3]):
        following=int(following*1000)
    elif("M" in sep_chunk[3]):
        following=int(following*1000000)
    else:
        following=int(following)
    
    name=sep_chunk[4]
    if(len(sep_chunk)>5):
      type_of_page=sep_chunk[5]
      bio="\n".join(sep_chunk[6:])
    else:
        type_of_page="unknown"
        bio="empty"
    # print(username,posts,followers,following,name,type_of_page,bio,sep='\n')
    return{"username":username,"posts":posts,"followers":followers,"following":following,"name":name,"type_of_pages":type_of_page,"bio":bio,}

print(parse_chunk(chunks[0]))
# Out:
# {'username': 'techie_koramangala', 'posts': 420, 'followers': 9800, 'following': 310, 'name': 'Arjun M.', 'type_of_pages': 'Software Engineer', 'bio': '💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'}

# %%
all_chunks=[]
for chunk in chunks:
    
        
    parsed_chunk=parse_chunk(chunk)
    all_chunks.append(parsed_chunk)

# %%
import json
s=json.dumps(all_chunks,indent=5)
with open("data.json",'w')as f:
    f.write(s)

# %% [markdown]
# # who has the maximum post
# let's write the code

# %%
max=0
for chunk in all_chunks:
    if(max<chunk['posts']):
      max=chunk['posts']
      chunk_with_max_post=chunk

print(chunk_with_max_post)
# Out:
# {'username': 'startuphub_blr', 'posts': 2300, 'followers': 45000, 'following': 120, 'name': 'Startup Hub Bangalore', 'type_of_pages': 'Media', 'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %% [markdown]
# # who has the maximum followers
# let's write the code

# %%
max=0
for chunk in all_chunks:
    if(max<chunk['followers']):
       max=chunk['followers']
       chunk_with_max_followers=chunk

print(chunk_with_max_followers)
# Out:
# {'username': '_anujsinghal', 'posts': 1785, 'followers': 681000, 'following': 248, 'name': 'Anuj Singhal', 'type_of_pages': 'Digital creator', 'bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}

# %% [markdown]
# # who has the maximum following
# let's write the code

# %%
max=0
for chunk in all_chunks:
    if(max<chunk['following']):
       max=chunk['following']
       chunk_with_max_following=chunk

print(chunk_with_max_following)
# Out:
# {'username': 'bangalore_tech_bro', 'posts': 402, 'followers': 12500, 'following': 890, 'name': 'Rahul | HSR Hustler', 'type_of_pages': 'Entrepreneur', 'bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}

# %% [markdown]
# # How many categories (Digital creators, Non-profit foundation, etc do we have? How many people do we have?
# let's write the code

# %%
categories=set()
for chunk in all_chunks:
    categories.add(chunk['type_of_pages'])

print(categories,len(categories))
# Out:
# {'Media', 'Investor', 'Comedy', 'Blogger', 'Public Figure', 'Blog', 'Developer', 'Software Engineer', 'Artist + Coder', 'Frontend Dev', 'Engineer', 'Coder', 'Food & Drink', 'Cafe Explorer', 'Education', 'Lifestyle', 'Data Scientist', 'Full-stack Dev', 'Product Manager', 'Design', 'Cafe Nerd', 'Digital creator', 'Personal Blog', 'Backend Developer', 'Founder', 'Nonprofit organization', 'Educator', 'Entrepreneur', 'Tech', 'Tech Creator', 'Data Science', 'Community', 'Writer', 'Recruiter'} 34
